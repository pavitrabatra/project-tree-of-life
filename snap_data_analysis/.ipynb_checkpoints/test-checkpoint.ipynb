# %%
from graph_tool.all import *
import numpy as np

l1 = np.loadtxt("/mnt/hdd/IISER/5th Year/Domenico/Tree of Life/Code/re/jensen/layer1.edges")
l2 = np.loadtxt("/mnt/hdd/IISER/5th Year/Domenico/Tree of Life/Code/re/jensen/layer2.edges")
ug1 = Graph(directed=False)
ug2 = Graph(directed=False)
ug1.add_vertex(350)
ug1.add_edge_list(l1)
ug2.add_vertex(350)
ug2.add_edge_list(l2)
graph_draw(ug1,vertex_text = ug1.vertex_index)
graph_draw(ug2,vertex_text = ug2.vertex_index)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f9b782215d0, at 0x7f9b797cf550>
